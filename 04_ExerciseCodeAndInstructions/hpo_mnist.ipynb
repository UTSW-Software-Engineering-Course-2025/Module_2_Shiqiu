# %%
nEpochs=40  # orig, longer training
#nEpochs=3  # quick testing during development

# Select one (and only one) model to train
USE_CGAN = True
USE_CVAE = False
USE_CVAECGAN = False

# Extract model name based on boolean value above
model_name = ""
if USE_CGAN:
    model_name += "cgan"
elif USE_CVAE:
    model_name += "cvae"
elif USE_CVAECGAN:
    model_name += "cvaecgan"

# Double check model name is valid
if model_name not in {"cgan", "cvae", "cvaecgan"}:
    raise Exception("Double check you are only using one model. The current model name is invalid")

# %% [markdown]
# ## 1. Import 3rd party libraries

# %%
import os
import session_info
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

try:
    os.environ["CUDA_VISIBLE_DEVICES"]="1"
    gpus = tf.config.list_physical_devices("GPU")
    print(gpus)
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0], 
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=3300)]
    )
except:
    Warning("Unable To configure Tensorflow GPU")
    
# Import our own classes 
from vaegan.data import MNIST
from vaegan.conditional.callbacks import GenerateImagesConditional, SaveImagesConditional
from vaegan.gan_SOLUTIONS import ConditionalGAN
from vaegan.vae_SOLUTIONS import ConditionalVAE
from vaegan.conditional.models import ConditionalVAECGAN

#session_info.show()
# Out:
# 2025-05-30 10:01:11.523744: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748617271.549235   24207 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748617271.557130   24207 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748617271.576759   24207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748617271.576783   24207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748617271.576785   24207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748617271.576788   24207 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 3. Show some our data

# %%
# Create output directory if it doesn't exist yet.
output_dir = './outputs/mnist' + f"_hpo_{model_name}"
os.makedirs(output_dir, exist_ok=True)
    
# Instantiate the MNIST class containing our training data.
data = MNIST()

# One-hot encode the labels
n_classes = int(data.labels_train.max() + 1)
labels_onehot = tf.one_hot(data.labels_train, 
                           depth=n_classes,
                           dtype=tf.float32).numpy()

# Show some example images and their labels.
data.show_example_images(os.path.join(output_dir, 'example_images.png'))
# Out:
# I0000 00:00:1748617276.154390   24207 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3300 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:82:00.0, compute capability: 6.0
# /project/nanocourse/SWE_OOP/train11/Module_2_Materials/04_ExerciseCodeAndInstructions/HPO/vaegan/data.py:67: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## 4. Construct the model using the python class you completed

# %%
# Create the model. Note that we're using mostly the default arguments, but this is
# where you might want to play around with different loss weights.
tf.random.set_seed(1234)
hpo_params = {
    'n_latent_dims' : 4,
    'learning_rate': 0.001,
    'encoder_params' : {
        'conv_layer_units' : [16,64],
        'conv_layer_kernel_size' : [4,4,4,4],
        'conv_layer_strides' : [(1,1), (2,2)],
        'conv_layer_activation_function' : ['relu','relu'],
        'encoder_dense_layer_units' : [128],
        'decoder_dense_layer_units' : [],
    },
    'decoder_params' : {'conv_layer_units' : [16,64],
        'conv_layer_kernel_size' : [4,4],
        'conv_layer_strides' : [(1,1), (2,2)],
        'conv_layer_activation_function' : ['relu','relu'],
        'encoder_dense_layer_units' : [128],
        'decoder_dense_layer_units' : [],
    },
    'generator_params' : {
        'generator_conv_layer_units' : [128,128],
        'generator_conv_layer_kernel_size' : [4,4],
        'generator_conv_layer_strides' : [(2,2), (2,2)],
        'generator_conv_layer_activation_functions' : [tf.nn.leaky_relu,tf.nn.leaky_relu],
        'discriminator_dense_layer_units' : [128],
        'generator_dense_layer_units' : [],
    },
    'discriminator_params' : {
        'discriminator_conv_layer_units' : [32,64],
        'discriminator_conv_layer_kernel_size' : [4,4],
        'discriminator_conv_layer_strides' : [(1,1), (2,2)],
        'discriminator_conv_layer_activation_functions' : ['relu','relu'],
        'discriminator_dense_layer_units' : [],
        'generator_dense_layer_units' : [],
    }
}

if USE_CGAN:
    model = ConditionalGAN(n_classes=n_classes,
                                 n_latent_dims = hpo_params['n_latent_dims'],
                                 generator_params = hpo_params['generator_params'],
                                 discriminator_params = hpo_params['discriminator_params'])
if USE_CVAE:
    model = ConditionalVAE(n_classes=n_classes, 
                            n_latent_dims = hpo_params['n_latent_dims'],
                            encoder_params = hpo_params['encoder_params'],
                            decoder_params = hpo_params['decoder_params'],
    )
if USE_CVAECGAN:
    model = ConditionalVAECGAN(adv_loss_weight=10., 
                            n_classes=n_classes,
                            n_latent_dims = hpo_params['n_latent_dims'],
                            encoder_params=hpo_params['encoder_params'],
                            decoder_params=hpo_params['decoder_params'],
                            discriminator_params=hpo_params['discriminator_params']
    )


# This step tells Keras to compute the explicit output shapes of each layer.
# Otherwise, the layers will have dynamic/variable output shapes which is not
# compatible with saving and loading.

# All three models will use this input structure
model.compute_output_shape([(None, 32, 32, 1), (None, n_classes)])
if USE_CVAE or USE_CVAECGAN:
    model.decoder.compute_output_shape((None, n_classes + model.n_latent_dims))
if USE_CGAN or USE_CVAECGAN:
    model.discriminator.compute_output_shape((None, 32, 32, 1))
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Loaded version: vaegan.gan_SOLUTIONS
# Loaded version: vaegan.gan_SOLUTIONS

# %%
print("=== OVERALL MODEL ====")
model.summary()

if USE_CGAN:
    print("=== GENERATOR SUBMODEL ====")
    gen_in = tf.keras.layers.Input(model.n_latent_dims+model.n_classes)
    gen_out  = model.generator.call(gen_in) 
    gen = tf.keras.Model(gen_in, gen_out) 
    gen.summary()
    print("=== DISCRIMINATOR SUBMODEL ====")
    disc_in = tf.keras.layers.Input(model.image_shape) 
    disc_out  = model.discriminator.call(disc_in) 
    disc = tf.keras.Model(disc_in, disc_out) 
    disc.summary()
if USE_CVAE:
    print("=== ENCODER SUBMODEL ====")
    enc_in = tf.keras.layers.Input((32,32,1 + model.n_classes)) # 32x32x1 + 10 more in the last dim for the one-hot encoded class label
    enc_out  = model.encoder.call(enc_in) 
    enc = tf.keras.Model(enc_in, enc_out) 
    enc.summary()
    print("=== DECODER SUBMODEL ====")
    dec_in = tf.keras.layers.Input(model.n_latent_dims+model.n_classes) 
    dec_out  = model.decoder.call(dec_in) 
    dec = tf.keras.Model(dec_in, dec_out) 
    dec.summary()
if USE_CVAECGAN:
    print("=== ENCODER SUBMODEL ====")
    enc_in = tf.keras.layers.Input((32,32,1 + model.n_classes)) # 32x32x1 + 10 more in the last dim for the one-hot encoded class label
    enc_out  = model.encoder.call(enc_in) 
    enc = tf.keras.Model(enc_in, enc_out) 
    enc.summary()
    print("=== DECODER SUBMODEL ====")
    dec_in = tf.keras.layers.Input(model.n_latent_dims + model.n_classes) 
    dec_out  = model.decoder.call(dec_in) 
    dec = tf.keras.Model(dec_in, dec_out) 
    dec.summary()
    print("=== DISCRIMINATOR SUBMODEL ====")
    disc_in = tf.keras.layers.Input(model.image_shape) 
    disc_out  = model.discriminator.call(disc_in) 
    disc = tf.keras.Model(disc_in, disc_out) 
    disc.summary()
# Out:
# === OVERALL MODEL ====
# Model: "cgan"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  generator (Generator)       multiple                  648577
#
#  discriminator (MultiTaskDi  ((None, 1),               213995
#  scriminator)                 (None, 10))
#
# =================================================================
# Total params: 862578 (3.29 MB)
# Trainable params: 862380 (3.29 MB)
# Non-trainable params: 198 (792.00 Byte)
# _________________________________________________________________
# === GENERATOR SUBMODEL ====
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 14)]              0
#
#  dense_to_conv (Dense)       (None, 8192)              122880
#
#  leaky_relu_dense_to_conv (  (None, 8192)              0
#  Activation)
#
#  reshape (Reshape)           (None, 8, 8, 128)         0
#
#  tconv1 (Conv2DTranspose)    (None, 16, 16, 128)       262272
#
#  leaky_relu1 (Activation)    (None, 16, 16, 128)       0
#
#  tconv0 (Conv2DTranspose)    (None, 32, 32, 128)       262272
#
#  leaky_relu0 (Activation)    (None, 32, 32, 128)       0
#
#  conv_out (Conv2D)           (None, 32, 32, 1)         1153
#
#  sigmoid_out (Activation)    (None, 32, 32, 1)         0
#
# =================================================================
# Total params: 648577 (2.47 MB)
# Trainable params: 648577 (2.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# === DISCRIMINATOR SUBMODEL ====
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 1)]          0         []
#
#  conv0 (Conv2D)              (None, 32, 32, 32)           544       ['input_2[0][0]']
#
#  bn0 (BatchNormalization)    (None, 32, 32, 32)           128       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 32, 32, 32)           0         ['bn0[0][0]']
#
#  conv1 (Conv2D)              (None, 16, 16, 64)           32832     ['relu0[0][0]']
#
#  bn1 (BatchNormalization)    (None, 16, 16, 64)           256       ['conv1[0][0]']
#
#  relu1 (Activation)          (None, 16, 16, 64)           0         ['bn1[0][0]']
#
#  flatten (Flatten)           (None, 16384)                0         ['relu1[0][0]']
#
#  dense_real (Dense)          (None, 1)                    16385     ['flatten[0][0]']
#
#  dense_class (Dense)         (None, 10)                   163850    ['flatten[0][0]']
#
#  sigmoid_real (Activation)   (None, 1)                    0         ['dense_real[0][0]']
#
#  softmax_class (Softmax)     (None, 10)                   0         ['dense_class[0][0]']
#
# ==================================================================================================
# Total params: 213995 (835.92 KB)
# Trainable params: 213803 (835.17 KB)
# Non-trainable params: 192 (768.00 Byte)
# __________________________________________________________________________________________________

# %%
_ = model([data.images_train[:1], labels_onehot[:1]])
# Out:
# I0000 00:00:1748617279.242477   24207 cuda_dnn.cc:529] Loaded cuDNN version 90300

# %% [markdown]
# ## 6. Compile the model

# %%
# Compile the model with an optimizer. The learning rate of the optimizer can be
# specified here. Normally, this is also where you would select a loss function
# and any metrics. However, our custom model defines the loss functions inside
# its __init__ constructor, so we don't need to do that here. 

model.compile(optimizer=tf.keras.optimizers.legacy.Adam(lr=hpo_params['learning_rate']))

# Instantiate our custom callback to save a few example reconstructions and
# generated images after each epoch.
if USE_CGAN:
    save_images_callback = GenerateImagesConditional(output_dir=output_dir, 
                                                    model=model,
                                                    example_labels=labels_onehot[:10],
                                                    n_generated_images=10,
                                                    n_latent_dims=model.n_latent_dims)
elif USE_CVAE or USE_CVAECGAN:
    save_images_callback = SaveImagesConditional(output_dir=output_dir, 
                                                model=model,
                                                example_images=data.images_train[:10],
                                                example_labels=labels_onehot[:10],
                                                n_generated_images=10,
                                                n_latent_dims=model.n_latent_dims)
# Out:
# /project/nanocourse/SWE_OOP/shared/CondaEnvs/lib/python3.12/site-packages/tf_keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# ## 7. Train (fit) the model on the data

# %%
# Train the model. Just like any off-the-shelf Keras model, we just call fit.
# Under the hood, Keras will call the train_step method of our custom subclass
# on each mini-batch and automatically loop through the training data. It will
# take care of all the details, like converting numpy arrays to tensors, showing
# a progress bar, and tracking the loss over the epochs.
logs = model.fit([data.images_train, labels_onehot],
                 batch_size=128,
                 epochs=nEpochs,
                 callbacks=[save_images_callback])
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748617285.124853   24621 service.cc:152] XLA service 0x2aae846537e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748617285.124887   24621 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1748617285.317155   24621 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 469/469 [==============================] - 36s 58ms/step - gen_loss: 10.6949 - disc_loss: 0.2054 - top_1_acc: 0.9510
# Epoch 2/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 0.2479 - disc_loss: 0.0856 - top_1_acc: 0.9786
# Epoch 3/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 0.0161 - disc_loss: 0.0670 - top_1_acc: 0.9834
# Epoch 4/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 24.0600 - disc_loss: 0.1841 - top_1_acc: 0.9776
# Epoch 5/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 2.9056 - disc_loss: 0.1115 - top_1_acc: 0.9849
# Epoch 6/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 5.0939 - disc_loss: 0.1148 - top_1_acc: 0.9859
# Epoch 7/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 5.9556 - disc_loss: 0.0908 - top_1_acc: 0.9872
# Epoch 8/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 15.4257 - disc_loss: 0.0930 - top_1_acc: 0.9894
# Epoch 9/40
# 469/469 [==============================] - 27s 57ms/step - gen_loss: 9.1065 - disc_loss: 0.1220 - top_1_acc: 0.9881
# Epoch 10/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 7.5534 - disc_loss: 0.0851 - top_1_acc: 0.9906
# Epoch 11/40
# 469/469 [==============================] - 27s 57ms/step - gen_loss: 12.5595 - disc_loss: 0.1136 - top_1_acc: 0.9891
# Epoch 12/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 6.1885 - disc_loss: 0.0950 - top_1_acc: 0.9893
# Epoch 13/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 2.0891 - disc_loss: 0.0692 - top_1_acc: 0.9921
# Epoch 14/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 2.3423 - disc_loss: 0.0526 - top_1_acc: 0.9919
# Epoch 15/40
# 469/469 [==============================] - 27s 58ms/step - gen_loss: 3.2516 - disc_loss: 0.0560 - top_1_acc: 0.9922
# Epoch 16/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 2.3213 - disc_loss: 0.0672 - top_1_acc: 0.9928
# Epoch 17/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 5.3925 - disc_loss: 0.0783 - top_1_acc: 0.9930
# Epoch 18/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 2.0802 - disc_loss: 0.0552 - top_1_acc: 0.9933
# Epoch 19/40
# 469/469 [==============================] - 27s 59ms/step - gen_loss: 13.0176 - disc_loss: 0.0961 - top_1_acc: 0.9928
# Epoch 20/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 1.1369 - disc_loss: 0.0450 - top_1_acc: 0.9937
# Epoch 21/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 8.6649 - disc_loss: 0.0725 - top_1_acc: 0.9940
# Epoch 22/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 1.3091 - disc_loss: 0.0353 - top_1_acc: 0.9952
# Epoch 23/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 15.7424 - disc_loss: 0.0897 - top_1_acc: 0.9933
# Epoch 24/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 8.6214 - disc_loss: 0.0748 - top_1_acc: 0.9941
# Epoch 25/40
# 469/469 [==============================] - 28s 60ms/step - gen_loss: 16.2459 - disc_loss: 0.1172 - top_1_acc: 0.9922
# Epoch 26/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 3.6329 - disc_loss: 0.0429 - top_1_acc: 0.9952
# Epoch 27/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 11.9157 - disc_loss: 0.0863 - top_1_acc: 0.9935
# Epoch 28/40
# 469/469 [==============================] - 26s 56ms/step - gen_loss: 20.7212 - disc_loss: 0.0934 - top_1_acc: 0.9931
# Epoch 29/40
# 469/469 [==============================] - 32s 68ms/step - gen_loss: 6.3454 - disc_loss: 0.0699 - top_1_acc: 0.9947
# Epoch 30/40
# 469/469 [==============================] - 39s 84ms/step - gen_loss: 6.5482 - disc_loss: 0.0626 - top_1_acc: 0.9948
# Epoch 31/40
# 469/469 [==============================] - 42s 90ms/step - gen_loss: 13.6938 - disc_loss: 0.0604 - top_1_acc: 0.9948
# Epoch 32/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 10.7367 - disc_loss: 0.0660 - top_1_acc: 0.9950
# Epoch 33/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 27.5608 - disc_loss: 0.0944 - top_1_acc: 0.9944
# Epoch 34/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 9.1066 - disc_loss: 0.0812 - top_1_acc: 0.9951
# Epoch 35/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 7.0001 - disc_loss: 0.0882 - top_1_acc: 0.9934
# Epoch 36/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 21.9918 - disc_loss: 0.0994 - top_1_acc: 0.9942
# Epoch 37/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 5.3312 - disc_loss: 0.0660 - top_1_acc: 0.9955
# Epoch 38/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 15.2053 - disc_loss: 0.1095 - top_1_acc: 0.9946
# Epoch 39/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 2.9649 - disc_loss: 0.0649 - top_1_acc: 0.9957
# Epoch 40/40
# 469/469 [==============================] - 42s 89ms/step - gen_loss: 4.3033 - disc_loss: 0.0524 - top_1_acc: 0.9959

# %% [markdown]
# ## 8. Training saves results to disk, now also plot training curves

# %%
# Plot the training curves, which are stored in logs.history as a dict. Keys of
# this dict are the metric names, while the corresponding values are arrays.
fig, ax = plt.subplots()

for loss_name in ['enc_loss', 'dec_loss', 'disc_loss', 'gen_loss']:
    if loss_name in logs.history.keys():
        loss_values = logs.history[loss_name]
        x = np.arange(len(loss_values))
        ax.plot(x, loss_values, label=loss_name)
        
ax.legend()
ax.set_xlabel('Epoch')
fig.savefig(os.path.join(output_dir, 'training_curves.png'), transparent=False)
# fig.show()

# Save the model 
model.save(os.path.join(output_dir, model_name))
# Out:
# INFO:tensorflow:Assets written to: ./outputs/mnist_hpo_cgan/cgan/assets
# INFO:tensorflow:Assets written to: ./outputs/mnist_hpo_cgan/cgan/assets

# %% [markdown]
# # HPO Exercise: Your Turn!
# - Take the code from above, and implement a grid search over at least 2 hyper parameters (try at least 3 different values for each hyper parameter)
#   - Train each model for at least 20 epochs.
#   - You can modify both hyperparameters at the same time, or perform two completely separate sequential tunings.
#   - You can find some suggested hyperparameter ranges / values in the table below:
#
# Hyperparameter | [min value, max value]
# ----------------|-----------------------
# Number of latent dims: |   [2, 128]
# Number of Convolutional layers: |     [1, 6]
# Number of convolutional layer units:|     [4, 256]
# Convolutional kernel size: | [2, 5]
# Convolutional layer activation functions (choose): |  ['relu', 'elu', 'linear', tf.nn.leaky_relu, 'softmax', 'sigmoid']
# Dense layer units: | [4, 256]
# Learning Rate:  | [0.01, 0.000001]

# %%
## !!!!IMPORTANT!!!!
## Keep the seed the same across ALL HPO experiments. Be sure to reinitialize for EVERY new model.
tf.random.set_seed(1234)
## !!!!IMPORTANT!!!!


# Instantiate a container with the hyperparameter(s) you want to test

learning_rate = 1e-4
latent_dim = 64

# Instantiate a model for a hyperparameter (combination)
## Note: I would recommend naming your model with the specific HPO you are trying at the moment.
model_n= f"{model_name}_lr{learning_rate}_z{latent_dim}"


# Build a model with input / output dimensions
if USE_CGAN:
    model = ConditionalGAN(n_classes=n_classes,
                                 n_latent_dims = hpo_params['n_latent_dims'],
                                 generator_params = hpo_params['generator_params'],
                                 discriminator_params = hpo_params['discriminator_params'])
if USE_CVAE:
    model = ConditionalVAE(n_classes=n_classes, 
                            n_latent_dims = hpo_params['n_latent_dims'],
                            encoder_params = hpo_params['encoder_params'],
                            decoder_params = hpo_params['decoder_params'],
    )
if USE_CVAECGAN:
    model = ConditionalVAECGAN(adv_loss_weight=10., 
                            n_classes=n_classes,
                            n_latent_dims = hpo_params['n_latent_dims'],
                            encoder_params=hpo_params['encoder_params'],
                            decoder_params=hpo_params['decoder_params'],
                            discriminator_params=hpo_params['discriminator_params']
    )

# Compile the model

# Fit model to the data

# Plot the training curves for the model

# Save the model 

# Assuming you are using the provided callbacks and save the model/outputs appropriately,
# You should be able to use the provided `image_viewer` to look at the fakes and/or recons just by
# Passing in a model's name/directory.
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Loaded version: vaegan.gan_SOLUTIONS
# Loaded version: vaegan.gan_SOLUTIONS

# %%
import matplotlib.pyplot as plt
from itertools import product
## !!!!IMPORTANT!!!!
## Keep the seed the same across ALL HPO experiments. Be sure to reinitialize for EVERY new model.
tf.random.set_seed(1234)
## !!!!IMPORTANT!!!!


# Instantiate a container with the hyperparameter(s) you want to test
latent_dims = [32, 64, 128]
learning_rates = [1e-4,1e-5, 1e-6]


os.makedirs("saved_models", exist_ok=True)
os.makedirs("training_curves", exist_ok=True)

# === Loop over grid ===
for latent_dim, lr in product(latent_dims, learning_rates):

    # Instantiate a model for a hyperparameter (combination)
    ## Note: I would recommend naming your model with the specific HPO you are trying at the moment.
    model_nm = f"{model_name}_latent{latent_dim}_lr{lr:.0e}"
    os.makedirs(model_nm, exist_ok=True)
    print(f"\n\n=== Training model: {model_nm} ===")

    # Build a model with input / output dimensions

    if USE_CGAN:
        model = ConditionalGAN(n_classes=n_classes,
                                 n_latent_dims = latent_dim,
                                 generator_params = hpo_params['generator_params'],
                                 discriminator_params = hpo_params['discriminator_params'])
    if USE_CVAE:
        model = ConditionalVAE(n_classes=n_classes, 
                                n_latent_dims = latent_dim,
                                encoder_params = hpo_params['encoder_params'],
                                decoder_params = hpo_params['decoder_params'],
        )
    if USE_CVAECGAN:
        model = ConditionalVAECGAN(adv_loss_weight=10., 
                                n_classes=n_classes,
                                n_latent_dims = latent_dim,
                                encoder_params=hpo_params['encoder_params'],
                                decoder_params=hpo_params['decoder_params'],
                                discriminator_params=hpo_params['discriminator_params']
        )
    if USE_CGAN:
        save_images_callback = GenerateImagesConditional(output_dir=model_nm, 
                                                    model=model,
                                                    example_labels=labels_onehot[:10],
                                                    n_generated_images=10,
                                                    n_latent_dims=model.n_latent_dims)
    elif USE_CVAE or USE_CVAECGAN:
        save_images_callback = SaveImagesConditional(output_dir=model_nm, 
                                                model=model,
                                                example_images=data.images_train[:10],
                                                example_labels=labels_onehot[:10],
                                                n_generated_images=10,
                                                n_latent_dims=model.n_latent_dims)
    

    model.build(input_shape=[(None, 32, 32, 1), (None, 10)])
    # Compile the model
    model.compile(
        optimizer=tf.keras.optimizers.legacy.Adam(lr),
        run_eagerly=False
    )
    # Fit model to the data
    history = model.fit([data.images_train, labels_onehot],
                 batch_size=128,
                 epochs=nEpochs,
                 callbacks=[save_images_callback])

    # Save the model 
    _ = model([data.images_train[:1], labels_onehot[:1]])
    model.save(f"saved_models/{model_nm}")

    
    # Plot the training curves for the model
    fig, ax = plt.subplots()

    for loss_name in ['enc_loss', 'dec_loss', 'disc_loss', 'gen_loss']:
        if loss_name in logs.history.keys():
            loss_values = logs.history[loss_name]
            x = np.arange(len(loss_values))
            ax.plot(x, loss_values, label=loss_name)
            
    ax.legend()
    ax.set_xlabel('Epoch')
    fig.savefig(f'training_curves/{model_nm}_training_curves.png', transparent=False)

    print(f"Finished training {model_nm}")
# Assuming you are using the provided callbacks and save the model/outputs appropriately,
# You should be able to use the provided `image_viewer` to look at the fakes and/or recons just by
# Passing in a model's name/directory.
# Out:
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# === Training model: cgan_latent32_lr1e-04 ===
# Loaded version: vaegan.gan_SOLUTIONS
# Loaded version: vaegan.gan_SOLUTIONS
# Epoch 1/40
# 469/469 [==============================] - 32s 55ms/step - gen_loss: 14.4626 - disc_loss: 0.2175 - top_1_acc: 0.9457
# Epoch 2/40
# 469/469 [==============================] - 35s 75ms/step - gen_loss: 1.4562 - disc_loss: 0.0972 - top_1_acc: 0.9782
# Epoch 3/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 0.9813 - disc_loss: 0.0955 - top_1_acc: 0.9841
# Epoch 4/40
# 469/469 [==============================] - 34s 73ms/step - gen_loss: 40.3710 - disc_loss: 0.0987 - top_1_acc: 0.9826
# Epoch 5/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 32.5344 - disc_loss: 0.0747 - top_1_acc: 0.9883
# Epoch 6/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 0.2881 - disc_loss: 0.0476 - top_1_acc: 0.9900
# Epoch 7/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 0.1798 - disc_loss: 0.0266 - top_1_acc: 0.9930
# Epoch 8/40
# 469/469 [==============================] - 30s 64ms/step - gen_loss: 41.0381 - disc_loss: 0.0465 - top_1_acc: 0.9907
# Epoch 9/40
# 469/469 [==============================] - 29s 61ms/step - gen_loss: 31.3789 - disc_loss: 0.0538 - top_1_acc: 0.9909
# Epoch 10/40
# 469/469 [==============================] - 32s 68ms/step - gen_loss: 17.6102 - disc_loss: 0.0570 - top_1_acc: 0.9921
# Epoch 11/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 4.4455 - disc_loss: 0.0565 - top_1_acc: 0.9916
# Epoch 12/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 46.0411 - disc_loss: 0.0611 - top_1_acc: 0.9919
# Epoch 13/40
# 469/469 [==============================] - 27s 57ms/step - gen_loss: 13.0220 - disc_loss: 0.0575 - top_1_acc: 0.9928
# Epoch 14/40
# 469/469 [==============================] - 41s 87ms/step - gen_loss: 11.4865 - disc_loss: 0.0443 - top_1_acc: 0.9934
# Epoch 15/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 20.1809 - disc_loss: 0.0872 - top_1_acc: 0.9918
# Epoch 16/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 2.5926 - disc_loss: 0.0470 - top_1_acc: 0.9942
# Epoch 17/40
# 469/469 [==============================] - 41s 88ms/step - gen_loss: 8.1956 - disc_loss: 0.0663 - top_1_acc: 0.9937
# Epoch 18/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 5.4772 - disc_loss: 0.0451 - top_1_acc: 0.9940
# Epoch 19/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 11.9630 - disc_loss: 0.0589 - top_1_acc: 0.9945
# Epoch 20/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 11.5857 - disc_loss: 0.0633 - top_1_acc: 0.9942
# Epoch 21/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 21.0405 - disc_loss: 0.0532 - top_1_acc: 0.9947
# Epoch 22/40
# 469/469 [==============================] - 37s 78ms/step - gen_loss: 17.5858 - disc_loss: 0.0614 - top_1_acc: 0.9954
# Epoch 23/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 9.3708 - disc_loss: 0.0570 - top_1_acc: 0.9943
# Epoch 24/40
# 469/469 [==============================] - 26s 55ms/step - gen_loss: 13.4514 - disc_loss: 0.0455 - top_1_acc: 0.9955
# Epoch 25/40
# 469/469 [==============================] - 38s 81ms/step - gen_loss: 28.6121 - disc_loss: 0.0699 - top_1_acc: 0.9951
# Epoch 26/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 12.8257 - disc_loss: 0.0533 - top_1_acc: 0.9948
# Epoch 27/40
# 469/469 [==============================] - 42s 90ms/step - gen_loss: 4.8561 - disc_loss: 0.0436 - top_1_acc: 0.9962
# Epoch 28/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 14.7624 - disc_loss: 0.0601 - top_1_acc: 0.9962
# Epoch 29/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 2.5922 - disc_loss: 0.0314 - top_1_acc: 0.9961
# Epoch 30/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 14.6915 - disc_loss: 0.0763 - top_1_acc: 0.9946
# Epoch 31/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 1.2800 - disc_loss: 0.0332 - top_1_acc: 0.9961
# Epoch 32/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 15.6639 - disc_loss: 0.0533 - top_1_acc: 0.9964
# Epoch 33/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 0.5417 - disc_loss: 0.0203 - top_1_acc: 0.9978
# Epoch 34/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 10.9329 - disc_loss: 0.0527 - top_1_acc: 0.9961
# Epoch 35/40
# 469/469 [==============================] - 43s 91ms/step - gen_loss: 16.4960 - disc_loss: 0.0501 - top_1_acc: 0.9955
# Epoch 36/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 6.5135 - disc_loss: 0.0416 - top_1_acc: 0.9972
# Epoch 37/40
# 469/469 [==============================] - 40s 85ms/step - gen_loss: 16.9722 - disc_loss: 0.0438 - top_1_acc: 0.9959
# Epoch 38/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 19.1778 - disc_loss: 0.0423 - top_1_acc: 0.9971
# Epoch 39/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 8.1434 - disc_loss: 0.0321 - top_1_acc: 0.9970
# Epoch 40/40
# 469/469 [==============================] - 40s 86ms/step - gen_loss: 15.0474 - disc_loss: 0.0587 - top_1_acc: 0.9963
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 1, 32), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201ac7f20>, 46914463815184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 1, 32), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201ac7f20>, 46914463815184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20167320>, 46944022773664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20167320>, 46944022773664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab2679f5f0>, 46944022768064), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab2679f5f0>, 46944022768064), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb3650>, 46944022767984), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb3650>, 46944022767984), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 32, 64), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb2a50>, 46944022760464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 32, 64), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb2a50>, 46944022760464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb1340>, 46944022761264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb1340>, 46944022761264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20385430>, 46944022759264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20385430>, 46944022759264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203aee10>, 46944022759344), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203aee10>, 46944022759344), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203adbe0>, 46914464583872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203adbe0>, 46914464583872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20353050>, 46914464582832), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20353050>, 46914464582832), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 10), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20350f50>, 46914464585632), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 10), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20350f50>, 46914464585632), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20483d70>, 46914464591872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20483d70>, 46914464591872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 1, 32), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201ac7f20>, 46914463815184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 1, 32), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201ac7f20>, 46914463815184), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20167320>, 46944022773664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20167320>, 46944022773664), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab2679f5f0>, 46944022768064), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab2679f5f0>, 46944022768064), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb3650>, 46944022767984), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(32,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb3650>, 46944022767984), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 32, 64), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb2a50>, 46944022760464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4, 4, 32, 64), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb2a50>, 46944022760464), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb1340>, 46944022761264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2ab201cb1340>, 46944022761264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20385430>, 46944022759264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20385430>, 46944022759264), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203aee10>, 46944022759344), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(64,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203aee10>, 46944022759344), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203adbe0>, 46914464583872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 1), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab203adbe0>, 46914464583872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20353050>, 46914464582832), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(1,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20353050>, 46914464582832), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 10), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20350f50>, 46914464585632), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(16384, 10), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20350f50>, 46914464585632), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20483d70>, 46914464591872), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10,), dtype=tf.float32, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x2aab20483d70>, 46914464591872), {}).
# INFO:tensorflow:Assets written to: saved_models/cgan_latent32_lr1e-04/assets
# INFO:tensorflow:Assets written to: saved_models/cgan_latent32_lr1e-04/assets
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in TF-Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Finished training cgan_latent32_lr1e-04
#
#
# === Training model: cgan_latent32_lr1e-05 ===
# Loaded version: vaegan.gan_SOLUTIONS
# Loaded version: vaegan.gan_SOLUTIONS
# Epoch 1/40
# 311/469 [==================>...........] - ETA: 13s - gen_loss: 16.0167 - disc_loss: 0.2781 - top_1_acc: 0.9290
